# %% [markdown]
# # Analysis of the house sales price in Seattle
# Group Members: Chen Chen, Anqian Li, Yaqiong Liu

# %% [markdown]
# ![title](portada_Madison_Park_House_TBp_002.jpg)

# %% [markdown]
# ## PART I: Background information
# After a while of findings, We decided to use this dataset contains house sale prices for King County. King County is a county located in the U.S. State of Washington. The population was 2,188,649 in the 2017 census estimate. King County is the most populous county in Washington, and the 13th most popular County in the United States. The county seat in Seattle. which is the state's largest city. We know that house prices are affected by many different factors, as the size of the house is not the only factor that has a significant influence. For example, a house with more bedrooms and bathrooms might have a higher price compared to the other houses in the same community. A house has a view of waterfront might cost much than the houses with similar size but no views of waterfront. We want to deeply investigate, which factors affect the house price in King County and especially how much influence they have. We would like to focus on the house price changes in Seattle. The data we choose includes houses sold between May 2014 and May 2015.
#
# #### Can obtain the data from  the below url:
# https://www.kaggle.com/harlfoxem/housesalesprediction

# %% [markdown]
# ### A. A discussion of each of the variables included in the dataset, and what the observational unit is:
#
# - Variables:
#
#   Numerical:
#     - Id: This is a unique identifier for each house.
#     - Date: This variable indicates the date when the house was sold.
#     - Price: This is the price of the house when it was sold.
#     - Bedrooms: This variable is the number of bedrooms per house.
#     - Bathrooms: This variable is obtained by the number of bathrooms / the total number of rooms of the house.
#     - Sqft_living: This is the total square footage of the home.
#     - Sqft_lot: This is the total square footage of the lot.
#     - Floors: Total floors (levels) in-house.
#     - View: This is the number that the house has been viewed.
#     - Condition: How good the overall condition of the house is. This range from 1 to 5.
#     - Grade: overall grade given to the housing unit, based on the King County grading system. Range from 1 to 13. The specific King County grading system can be found at:
#     https://info.kingcounty.gov/assessor/esales/Glossary.aspx?type=r
#
#     - Sqft_above: square footage of house apart from the basement.
#     - Sqft_basement: square footage of the basement.
#     - Yr_built: The year when the house was originally built.
#     - Yr_renovated: Year when the house was renovated. If there is no innovation, then the value of this variable is 0.
#     - Lat: Latitude coordinate of the house.
#     - Long: Longitude coordinate of the house.
#     - Sqft_living15: Living room area in 2015 (implies -- some renovations). This might or might not have affected the lot size area.
#     - Sqft_lot15lot: Size area in 2015(implies-- some renovations).
#
#   Categorical:
#     - Waterfront: House which has a view to a waterfront. 0 indicates that the house does not have a view of a waterfront; 1 indicates that the house has a view of a waterfront.
#     - Zipcode: the zip code of where the house is.
#
#
# - Observation unit:
#     Each row is an observational unit. One row for each transaction history.
#
# ### B. Discussion of how the data is collected:
# - This dataset contains house sale prices for King County, which includes Seattle. It includes homes sold between May 2014 and May 2015.
#
# ### C. “Common knowledge”:
# - The average house price in Seattle in 2015 is $733,400.
# - The most important considerations people have when buying a house are the location (eg: the view of the house); neighborhood (eg: whether it is near a good academic institution or not) and the size of the house.
#
# ### D. A review of other house sales price in research or studies that have been done:
#
# - There is a study based on different statistical models on predicting the house sales price by a data analyst Burhan Y. Kiyakoglu posted on Kaggles. He uses the square footage of living area (sqft_living), waterfront, view and grade as the predictors and price as outcome varaible. He fits the data in linear regression model; polynomial regression model (degree = 2, 3); k-nn regression models with different number of neighbors (15, 25, 27) to see which regression model perform the best. After seeing the results of different tests, he comes into the conclusion that polynomial regression model fits the best, with a R-square of 0.722 for degree = 3 and 0.716 for degree = 2. However, he also mentions that each model might be useful depending to the situation. The complete report can be seen at:
# https://www.kaggle.com/burhanykiyakoglu/predicting-house-prices

# %% [markdown]
# #  PART II: Exploratory Analysis of the Data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Summary statistics and the distributional shape of variables in the data

# %%
house = pd.read_csv('kc_house_data.csv')

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# get rid of the duplicated id
house = house[~house.id.duplicated()]

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21436 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21436 non-null int64
# date             21436 non-null object
# price            21436 non-null float64
# bedrooms         21436 non-null int64
# bathrooms        21436 non-null float64
# sqft_living      21436 non-null int64
# sqft_lot         21436 non-null int64
# floors           21436 non-null float64
# waterfront       21436 non-null int64
# view             21436 non-null int64
# condition        21436 non-null int64
# grade            21436 non-null int64
# sqft_above       21436 non-null int64
# sqft_basement    21436 non-null int64
# yr_built         21436 non-null int64
# yr_renovated     21436 non-null int64
# zipcode          21436 non-null int64
# lat              21436 non-null float64
# long             21436 non-null float64
# sqft_living15    21436 non-null int64
# sqft_lot15       21436 non-null int64
# ...

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.143600e+04  2.143600e+04  21436.000000  21436.000000  21436.000000
# mean   4.580765e+09  5.405293e+05      3.371571      2.117349   2082.704936
# std    2.876590e+09  3.676893e+05      0.929205      0.769913    919.146469
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123700e+09  3.221500e+05      3.000000      1.750000   1430.000000
# 50%    3.904921e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.308675e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.143600e+04  21436.000000  21436.000000  21436.000000  21436.000000
# mean   1.513564e+04      1.496198      0.007604      0.235118      3.410384
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
plt.hist(house.price) 
plt.title('The histogram of price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# the histogram of price looks pretty right-skewed, so we decided to cut out the 3% outliers of prices

# %%
house1 = house.sort_values(by='price').iloc[0:int(21436*(1-0.03)),]
plt.hist(house1.price)
plt.title('The histogram of price after cutting out the 3% outliers')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# We only look at the areas in Seattle

# %%
house1 = house1.loc[house1['zipcode'].astype(str).str[0:3] == '981',]
house1.shape
# Out:
# (8659, 21)

# %% [markdown]
# The distributional shape of variables in the data

# %%
temp = house1[['price','bedrooms','bathrooms','sqft_living15','sqft_lot15','grade','condition','yr_built']]
sns.pairplot(temp.iloc[::10,:],diag_kind='kde',diag_kws=dict(shade=True), kind = 'reg')
plt.suptitle('The distributional shape of data and the potential relationships between different variables ', 
             y = 1, fontsize = 'xx-large')
plt.show()
# Out:
# /Users/LEEANQIAN/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - From the above plots, we find out that there are potential linear asociations between the following pairs of variable: price and bedroom number; price and bathroom number; price and square footage of living area; price and the grade of house; price and the grade of condition.

# %%
# let's look at the correlation coefficient matrix for the above variables.
temp.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living15  sqft_lot15  \
# price          1.000000  0.297028   0.457895       0.539749   -0.060181
# bedrooms       0.297028  1.000000   0.470083       0.294015    0.124577
# bathrooms      0.457895  0.470083   1.000000       0.346141   -0.048097
# sqft_living15  0.539749  0.294015   0.346141       1.000000    0.286864
# sqft_lot15    -0.060181  0.124577  -0.048097       0.286864    1.000000
# grade          0.638840  0.271229   0.576768       0.459546   -0.040179
# condition      0.167422  0.088295  -0.004369       0.071135    0.056026
# yr_built      -0.070106  0.025668   0.425837      -0.010747   -0.102494
#
#                   grade  condition  yr_built
# price          0.638840   0.167422 -0.070106
# bedrooms       0.271229   0.088295  0.025668
# bathrooms      0.576768  -0.004369  0.425837
# sqft_living15  0.459546   0.071135 -0.010747
# sqft_lot15    -0.040179   0.056026 -0.102494
# grade          1.000000  -0.055033  0.397497
# ...

# %% [markdown]
# - As we can see from the matrix that bathrooms; sqft_living15; grade seems to have a high linear relationship with price. Based on the correlations of predictor varaibles, we can see that there is no multi-colinearity problem as the correlation coefficients are all below 0.6 (range from -0.04 to 0.57).

# %% [markdown]
# ### Guiding question 1: What is the relationship between price and house location (zipcode and having a waterfront view or not)?

# %%
# change the variable zipcode to be of category type.
house1.zipcode = house1.zipcode.astype('category')

# %%
sns.countplot(x='zipcode',data=house1,order = house1['zipcode'].value_counts().index)
plt.xticks(rotation=90)
plt.title('The number of houses sold in each zipcode area')
plt.show()

# %% [markdown]
# It seems like during May 2014 to May 2015, the area with zip code 98103 has the most number of houses sold while areas with zip code 98148 has the least number of houses sold.

# %%
house1.groupby(['zipcode']).price.mean()
# Out:
# zipcode
# 98102    729486.148936
# 98103    577921.753356
# 98105    731586.098522
# 98106    318960.687879
# 98107    562859.576336
# 98108    355871.372973
# 98109    752567.447917
# 98112    829459.000000
# 98115    602629.663139
# 98116    600344.848297
# 98117    575643.410584
# 98118    403178.777328
# 98119    748140.857988
# 98122    600144.471429
# 98125    458589.915000
# 98126    424377.982955
# 98133    385523.224742
# 98136    534642.773077
# 98144    522501.065015
# 98146    357167.760714
# 98148    282049.821429
# 98155    400675.423341
# 98166    435234.232653
# 98168    241330.803030
# 98177    592149.686192
# 98178    305216.505837
# 98188    289327.074074
# 98198    302925.952727
# 98199    719973.723906
# Name: price, dtype: float64

# %%
mean_loc=house1.groupby('zipcode').price.mean()
mean_loc1=mean_loc.sort_values(ascending=False)
mean_loc1.plot(kind="bar")
plt.ylabel("average house price")
plt.title("Average House Sales Price in Different Locations")
plt.show()

# %% [markdown]
# - We find that on average, the house sales price would change based on the different zipcode location it is.
# - Meanwhile, we can see that the average house sales price of houses with zip code 98112 is the highest while the price of house with zip code 98168 is the lowest.

# %% [markdown]
# #### ANOVA for zipcode and price

# %%
model = smf.ols(formula='price ~ zipcode', data=house1)
results = model.fit()
print(sm.stats.anova_lm(results))
# Out:
#               df        sum_sq       mean_sq           F  PR(>F)
# zipcode     28.0  1.776488e+14  6.344599e+12  189.726364     0.0
# Residual  8630.0  2.885940e+14  3.344079e+10         NaN     NaN

# %% [markdown]
# - We can see that the F-test has a p-value of 0. Hence, we would consider that the location of the house(zipcode) has a statistically significant effect on house sales price.

# %% [markdown]
# #### ANOVA for waterfront and price

# %%
house1.waterfront = house1.waterfront.astype('category') # change the variable waterfront to be of category type.
model = smf.ols(formula='price ~ waterfront', data=house1)
results = model.fit()
print(sm.stats.anova_lm(results))
# Out:
#                 df        sum_sq       mean_sq           F        PR(>F)
# waterfront     1.0  7.110322e+12  7.110322e+12  134.065999  8.901912e-31
# Residual    8657.0  4.591325e+14  5.303598e+10         NaN           NaN

# %% [markdown]
# - We can see that the F-test has a p-value of approximately to 0. Hence, we would consider that having a waterfront view or not has a statistically significant effect on house sales price.

# %% [markdown]
# ### Guiding question 2: What is the relationship between price and the size of the hosue?

# %%
plt.scatter(house1.sqft_living15, house1.price, marker='.')
plt.title('The relationship between the size of living area and house price')
plt.xlabel("Living area's square footage")
plt.ylabel('House price')
plt.show()

# %% [markdown]
# From the plot we can see that there is a potential linear relationship between size of living area and the price of the house.

# %%
# The correlation coefficient of hosue living area and price.
np.corrcoef(house1.price,house1.sqft_living15)
# Out:
# array([[1.        , 0.53974874],
#        [0.53974874, 1.        ]])

# %% [markdown]
# The correlation between house sales price and square footage of living area is 0.5398. We would say that there is a moderately positive linear association between sales price and the size of living area.

# %% [markdown]
# ### Guiding question 3: What is the relationship between house sales price and the house condition/grade ?

# %%
sns.boxplot(y = 'condition', x = 'price', data = house1,
            orient = 'h', showmeans = True)
plt.title('box plots for the prices based on different condition of the house')
plt.show()

# %% [markdown]
# It appears that on average, the higher the house condition is, its house sales price would increase. Also, we can see that there are more outliers (mostly in higher prices) for condition 3, 4 and 5 while for houses with grade 1 or 2, the prices seems to be similar.

# %% [markdown]
# #### ANOVA for condition and price

# %%
model = smf.ols(formula='price ~ condition', data=house1)
results = model.fit()
print(sm.stats.anova_lm(results))
# Out:
#                df        sum_sq       mean_sq           F        PR(>F)
# condition     1.0  1.306886e+13  1.306886e+13  249.654892  1.831562e-55
# Residual   8657.0  4.531739e+14  5.234769e+10         NaN           NaN

# %% [markdown]
# - We can see that the F-test has a p-value of approximately to 0. Hence, we would consider that the condition of the house has a statistically significant effect on house sales price.

# %%
sns.boxplot(y = 'grade', x = 'price', data = house1,
            orient = 'h', showmeans = True)
plt.title('box plots for the prices based on different grade of the house')
plt.show()

# %% [markdown]
# The above plot shows that the higher grade a house is, the higher sales prices it has on average.

# %% [markdown]
# #### ANOVA for grade and price

# %%
model = smf.ols(formula='price ~ grade', data=house1)
results = model.fit()
print(sm.stats.anova_lm(results))
# Out:
#               df        sum_sq       mean_sq            F  PR(>F)
# grade        1.0  1.902813e+14  1.902813e+14  5969.183286     0.0
# Residual  8657.0  2.759615e+14  3.187727e+10          NaN     NaN

# %% [markdown]
# - We can see that the F-test has a p-value of 0. Hence, we would consider that the grade of the house has a statistically significant effect on house sales price.

# %% [markdown]
# ### Guiding question 4: Is there any relationship between price and condition based on they have waterfront view or not?

# %%
sns.boxplot(x='condition',y='price', data= house1,
            hue='waterfront')
plt.title('box plots for condition of a house and price based on having waterfront view or not')
plt.show()

# %% [markdown]
# It seems like there are not much houses has waterfront view for houses have a condition score 1 or 2. For condition 3, 4 and 5, we can see taht the average sales price is much higher if the house has a waterfront view.

# %% [markdown]
# # PART III: Data Modeling
# - We chose price as our response variable, and based on the correlation plot, we have eliminated some of the variables. As we can see from the EDA, the scatter plot of number of bedrooms and prices and the scatter plot of number of bathrooms seem to have positive linear relationships. We also find that the living area and price seems to have a considerably strong linear relationship. The plots also shown that the price seems to be positively associated with the house condition and the year when it was built. Finally, we also find that the location of the house (zipcode) and having a view of waterfront or not would also effect the house sales price.
# - Based on the above description, we decide to use zipcode, living area, condition, waterfront, number of bedrooms and bathrooms and the year built as our predictors. Then, we fit in a linear model to see which are the significant variables in predicting the house price.

# %%
model = smf.ols(formula='price ~ zipcode + sqft_living15 + condition + waterfront + bedrooms + bathrooms + yr_built',
                data=house1)
results = model.fit()
print(sm.stats.anova_lm(results))
# Out:
#                    df        sum_sq       mean_sq            F         PR(>F)
# zipcode          28.0  1.776488e+14  6.344599e+12   360.260609   0.000000e+00
# waterfront        1.0  1.223742e+13  1.223742e+13   694.868096  2.395169e-147
# sqft_living15     1.0  8.776339e+13  8.776339e+13  4983.402291   0.000000e+00
# condition         1.0  5.321023e+12  5.321023e+12   302.139652   1.521319e-66
# bedrooms          1.0  1.408805e+13  1.408805e+13   799.951374  2.251043e-168
# bathrooms         1.0  1.522156e+13  1.522156e+13   864.314124  3.897175e-181
# yr_built          1.0  2.084119e+12  2.084119e+12   118.340978   2.197987e-27
# Residual       8624.0  1.518785e+14  1.761114e+10          NaN            NaN

# %% [markdown]
# As we can see from the above ANOVA table, all of the predictors have a p-value near to 0. Hence, we say that all the predictors we chose are statistically significant in predicting house sales price.

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     525.0
# Date:                Sun, 09 Dec 2018   Prob (F-statistic):               0.00
# Time:                        22:12:51   Log-Likelihood:            -1.1441e+05
# No. Observations:                8659   AIC:                         2.289e+05
# Df Residuals:                    8624   BIC:                         2.291e+05
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
from sklearn import linear_model, preprocessing, model_selection
X = house1.loc[:, ['zipcode', 'sqft_living15', 'condition', 'waterfront', 'bedrooms', 'bathrooms', 'yr_built']]
y = house1.price
housemodel = linear_model.LinearRegression(fit_intercept = True)
cv = model_selection.ShuffleSplit(n_splits = 5, test_size=0.3, random_state = 0)
cv_linear = model_selection.cross_val_score(housemodel, X, y, cv = cv)
np.mean(cv_linear)
# Out:
# 0.5011967284502604

# %% [markdown]
# From the above cross validation result, we get that the average R^2 for linear models built on different data subsets is 0.5012, which is fairly large and not far from R^2 of our original model. Hence we would say that our model is reasonable.

# %% [markdown]
# #### Interpretation of the result:

# %% [markdown]
# For zipcode, we have 29 different levels, python makes 98102 as the base, and creates 28 coefficients by comparing the other 28 zipcodes with zipcode 90102.
# - On average, houses located in zipcode 98103 was sold 80450 points lower on house price compared with house sales price in zipcode 98102. This difference is statistically significant.
# - For houses with zipcode 98106, 98107, 98108, 98112, 98115, 98116, 98117, 98118, 98122, 98125, 98126, 98133, 98136, 98144, 98146, 98148, 98155, 98166, 98168, 98177, 98178, 98188, 98198, they all on average have a lower house sales price compared to houses in zipcode 98102, with the corresponding units listed in the above table in coefficients columns. The differences are all statistically significant.
# - For houses with zipcode 98105, 98109, 9811, 98199, they have a p-value greater than 0.05, hence we say that the differences are not statistically significant.

# %% [markdown]
# For waterfront, we have 2 different levels, python makes 0 (does not have a waterfront view) as the base, and creates 1 coefficient by comparing having a view of waterfront with does not have.
# - On average, houses with waterfront was sold 398600 dollars higher on house sales price compared with house sales price with no waterfront view.

# %% [markdown]
# For other variables:
# - As the sqft_living15 increases one unit, on average, the price of the house will increase 179.8853 dollars;
# - As the condition increases one unit, on average, the price of the house will increase 179.8853 dollars;
# - As the sqft_living15 increases one unit, on average, the price of the house will increase 27570 dollars;
# - As the bedrooms increases one unit, on average, the price of the house will increase 17510 dollars;
# - As the yr_built increases one unit, on average, the price of the house will decrease 614.3709 dollars.

# %% [markdown]
# We get a R-square of approcimately 0.673, which means that 67.3% of the variance in house sales prices can be explained by the zipcode of the house, the square footages of the house living area, the condition of the house, the view of waterfront, the number of bedrooms and bathrooms and the year when the house is built.

# %% [markdown]
# # Presentation

# %% [markdown]
# Please see the pdf version of the ppt presentation.
# Here is the link to our video presentation:
#
# https://youtu.be/tfYZtmyIRGc
